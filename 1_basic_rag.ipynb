# %%
from typing import List, TypedDict
import time

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate

from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 from typing import List, TypedDict
#       2 import time
# ----> 4 from langchain_community.document_loaders import PyPDFLoader
#       5 from langchain_community.vectorstores import FAISS
#       6 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#
# File <frozen importlib._bootstrap>:1406, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\python37\Lib\site-packages\langchain_community\document_loaders\__init__.py:740, in __getattr__(name)
#     738 def __getattr__(name: str) -> Any:
#     739     if name in _module_lookup:
# --> 740         module = importlib.import_module(_module_lookup[name])
#     741         return getattr(module, name)
#     742     raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File c:\python37\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\python37\Lib\site-packages\langchain_community\document_loaders\pdf.py:28
#      25 from langchain_core.documents import Document
#      26 from langchain_core.utils import get_from_dict_or_env
# ---> 28 from langchain_community.document_loaders.base import BaseLoader
#      29 from langchain_community.document_loaders.blob_loaders import Blob
#      30 from langchain_community.document_loaders.dedoc import DedocBaseLoader
#
# File c:\python37\Lib\site-packages\langchain_community\document_loaders\base.py:1
# ----> 1 from langchain_core.document_loaders import BaseBlobParser, BaseLoader
#       3 __all__ = [
#       4     "BaseBlobParser",
#       5     "BaseLoader",
#       6 ]
#
# File <frozen importlib._bootstrap>:1406, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\python37\Lib\site-packages\langchain_core\document_loaders\__init__.py:33, in __getattr__(attr_name)
#      31 def __getattr__(attr_name: str) -> object:
#      32     module_name = _dynamic_imports.get(attr_name)
# ---> 33     result = import_attr(attr_name, module_name, __spec__.parent)
#      34     globals()[attr_name] = result
#      35     return result
#
# File c:\python37\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File c:\python37\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\python37\Lib\site-packages\langchain_core\document_loaders\base.py:19
#      16     from langchain_core.documents.base import Blob
#      18 try:
# ---> 19     from langchain_text_splitters import RecursiveCharacterTextSplitter
#      21     _HAS_TEXT_SPLITTERS = True
#      22 except ImportError:
#
# File c:\python37\Lib\site-packages\langchain_text_splitters\__init__.py:8
#       1 """Text Splitters are classes for splitting text.
#       2
#       3 !!! note
#       4     `MarkdownHeaderTextSplitter` and `HTMLHeaderTextSplitter` do not derive from
#       5     `TextSplitter`.
#       6 """
# ----> 8 from langchain_text_splitters.base import (
#       9     Language,
#      10     TextSplitter,
#      11     Tokenizer,
#      12     TokenTextSplitter,
#      13     split_text_on_tokens,
#      14 )
#      15 from langchain_text_splitters.character import (
#      16     CharacterTextSplitter,
#      17     RecursiveCharacterTextSplitter,
#      18 )
#      19 from langchain_text_splitters.html import (
#      20     ElementType,
#      21     HTMLHeaderTextSplitter,
#      22     HTMLSectionSplitter,
#      23     HTMLSemanticPreservingSplitter,
#      24 )
#
# File c:\python37\Lib\site-packages\langchain_text_splitters\base.py:33
#      30     _HAS_TIKTOKEN = False
#      32 try:
# ---> 33     from transformers.tokenization_utils_base import PreTrainedTokenizerBase
#      35     _HAS_TRANSFORMERS = True
#      36 except ImportError:
#
# File c:\python37\Lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File c:\python37\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\python37\Lib\site-packages\transformers\utils\__init__.py:24
#      21 from packaging import version
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#      27     ImageProcessorArgs,
#      28     ModelArgs,
#      29     ModelOutputArgs,
#      30     auto_class_docstring,
#      31     auto_docstring,
#      32     get_args_doc_from_source,
#      33     parse_docstring,
#      34     set_min_indent,
#      35 )
#      36 from .backbone_utils import BackboneConfigMixin, BackboneMixin
#      37 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#
# File c:\python37\Lib\site-packages\transformers\utils\auto_docstring.py:30
#      22 import regex as re
#      24 from .doc import (
#      25     MODELS_TO_PIPELINE,
#      26     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      27     PT_SAMPLE_DOCSTRINGS,
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      33 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      36 AUTODOC_FILES = [
#      37     "configuration_*.py",
#      38     "modeling_*.py",
#    (...)
#      43     "feature_extractor_*.py",
#      44 ]
#
# File c:\python37\Lib\site-packages\transformers\utils\generic.py:51
#      47 logger = logging.get_logger(__name__)
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch
#      53     from ..model_debugging_utils import model_addition_debugger_context
#      56 # vendored from distutils.util
#
# File c:\python37\Lib\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# File c:\python37\Lib\site-packages\torch\__init__.py:263, in _load_dll_libraries()
#     259     err = ctypes.WinError(last_error)
#     260     err.strerror += (
#     261         f' Error loading "{dll}" or one of its dependencies.'
#     262     )
# --> 263     raise err
#     264 elif res is not None:
#     265     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\python37\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
import sys
print(sys.executable)
print(sys.version)

# %%
import sys
print(sys.executable)
print(sys.version)
import torch
print(torch.__version__)

# %%
import sys
print(sys.executable)
print(sys.version)
import torch
print(torch.__version__)

# %%
docs = (
    PyPDFLoader("./documents/book1.pdf").load() +
    PyPDFLoader("./documents/book2.pdf").load() +
    PyPDFLoader("./documents/book3.pdf").load()
)

# %%
len(docs)

# %%
# 2) Chunk
chunks = RecursiveCharacterTextSplitter(chunk_size=900, chunk_overlap=150).split_documents(docs)

# 3) Clean text to avoid UnicodeEncodeError (surrogates from PDF extraction)
for d in chunks:
    d.page_content = d.page_content.encode("utf-8", "ignore").decode("utf-8", "ignore")

# %%
len(chunks)

# %%
# 3) Index (fresh collection each run)
embeddings = OpenAIEmbeddings(model='text-embedding-3-large')
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k':4})

# %%
# 4) LLM + prompt
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
class State(TypedDict):
    question: str
    docs: List[Document]
    answer: str

# %%
def retrieve(state):
    q = state["question"]
    return {"docs": retriever.invoke(q)}

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Answer only from the context. If not in context, say you don't know."),
        ("human", "Question: {question}\n\nContext:\n{context}"),
    ]
)
def generate(state):
    context = "\n\n".join(d.page_content for d in state["docs"])
    out = (prompt | llm).invoke({"question": state["question"], "context": context})
    return {"answer": out.content}

# %%
g = StateGraph(State)
g.add_node("retrieve", retrieve)
g.add_node("generate", generate)
g.add_edge(START, "retrieve")
g.add_edge("retrieve", "generate")
g.add_edge("generate", END)
app = g.compile()

app

# %%
# 5) Run
res = app.invoke({"question": "WHat is a transformer in deep learning.", "docs": [], "answer": ""})
print(res["answer"])

# %%
print(res['docs'][0].page_content)
print('*'*100)
print(res['docs'][1].page_content)
print('*'*100)
print(res['docs'][2].page_content)
print('*'*100)
print(res['docs'][3].page_content)
